# %%
#Cell 1 (rendered as Markdown): The title should be "My Jupyter Notebook on IBM Data Science Experience", 
#in H1 header styling. The title does not need to be centered.

# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %%
#Cell 2 (rendered as Markdown): Your name, in bold characters. In the line below your name,
#write your current or desired occupation in regular font.

# %% [markdown]
# **Name :                Manali Nikam**
#
#
# __Desired Occupation:  Data Scientist at MasterCard__

# %%
#Cell 3 (rendered as Markdown): In italic formatting, write one or two sentences 
#about why you are interested in data #science. For example, you can start your first sentence 
#with "I am interested in data science because ...".

# %% [markdown]
# _I am interested in data science because it is the future and
# will be an important aspect of decision making and predictions._

# %%
#Cell 4 (rendered as Markdown): In H3 header styling, explain in a short 
#sentence what your code is supposed to do in Cell 5.

# %% [markdown]
# ### The code in Cell 4 will print out the even numbers from the input provided by user.

# %%
#Cell 5 (code cell): Your code, as described in Cell 4. It must be executed and must display an output. 
#Try to keep the code simple (it can even be "1 + 1").

# %%
# Python program to print Even Numbers in a List 
  
# list of numbers 
list1 = [10, 22, 4, 49, 61, 93] 
  
# iterating each number in list 
for num in list1: 
      
    # checking condition 
    if num % 2 == 0: 
       print(num, end = " ")
# Out:
# 10 22 4

# %%
#Cell 6 (rendered as Markdown): Using Markdown or HTML, this cell must include at least 3 of the following: 
#horizontal rule, bulleted list, numbered list, tables, 
#hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.

# %% [markdown]
# #Horizontal Rule
#
# Apples and Oranges...
#
# ---
#
# Vegetables
#
# ***
#
# Salads
#
# ___
#
# Rice

# %% [markdown]
# #Bulleted List
#
# - Main bullet point
#      - Sub bullet point

# %% [markdown]
# #Numbered List
#
# 1. Numbered item
# 1. Numbered item

# %% [markdown]
# #Strikethrough
#
# ~~This course work ends here~~

# %%
#The course assignment ends here.Thankyou for reviewing.
