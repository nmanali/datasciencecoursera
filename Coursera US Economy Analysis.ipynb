# %%
# Import the libraries

import pandas as pd
from bokeh.plotting import figure, output_file, show,output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4355dc47-5780-4a82-8aeb-0b824e51c425">Loading BokehJS ...</span>
#     </div>

# %%
def make_dashboard(x, gdp_change, unemployment, title, file_name):
    output_file(file_name)
    p = figure(title=title, x_axis_label='year', y_axis_label='%')
    p.line(x.squeeze(), gdp_change.squeeze(), color="firebrick", line_width=4, legend="% GDP change")
    p.line(x.squeeze(), unemployment.squeeze(), line_width=4, legend="% unemployed")
    show(p)

# %%
links={'GDP':'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_gdp.csv',\
       'unemployment':'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_unemployment.csv'}

# %%
#Creating Data frame ot capture the GDP

df_gdp_us = pd.read_csv(links["GDP"])
df_gdp_us.head()

print(df_gdp_us)
df_gdp_us.head()
# Out:
#     date  level-current  level-chained  change-current  change-chained
# 0   1948          274.8         2020.0            -0.7            -0.6
# 1   1949          272.8         2008.9            10.0             8.7
# 2   1950          300.2         2184.0            15.7             8.0
# 3   1951          347.3         2360.0             5.9             4.1
# 4   1952          367.7         2456.1             6.0             4.7
# 5   1953          389.7         2571.4             0.3            -0.6
# 6   1954          391.1         2556.9             8.9             7.1
# 7   1955          426.2         2739.0             5.6             2.1
# 8   1956          450.1         2797.4             5.5             2.1
# 9   1957          474.9         2856.3             1.5            -0.7
# 10  1958          482.0         2835.3             8.4             6.9
# 11  1959          522.5         3031.0             4.0             2.6
# ...

# %%
df_unemp_us = pd.read_csv(links['unemployment'])
print (df_unemp_us)
df_unemp_us.head()
# Out:
#     date  unemployment
# 0   1948      3.750000
# 1   1949      6.050000
# 2   1950      5.208333
# 3   1951      3.283333
# 4   1952      3.025000
# 5   1953      2.925000
# 6   1954      5.591667
# 7   1955      4.366667
# 8   1956      4.125000
# 9   1957      4.300000
# 10  1958      6.841667
# 11  1959      5.450000
# 12  1960      5.541667
# 13  1961      6.691667
# 14  1962      5.566667
# 15  1963      5.641667
# 16  1964      5.158333
# 17  1965      4.508333
# 18  1966      3.791667
# 19  1967      3.841667
# 20  1968      3.558333
# 21  1969      3.491667
# 22  1970      4.983333
# 23  1971      5.950000
# 24  1972      5.600000
# 25  1973      4.858333
# 26  1974      5.641667
# 27  1975      8.475000
# 28  1976      7.700000
# 29  1977      7.050000
# ..   ...           ...
# 39  1987      6.175000
# 40  1988      5.491667
# 41  1989      5.258333
# 42  1990      5.616667
# 43  1991      6.850000
# 44  1992      7.491667
# 45  1993      6.908333
# 46  1994      6.100000
# ...

# %%
df_unemploy = df_unemp_us[df_unemp_us['unemployment'] > 8.5]
df_unemploy.head()
# Out:
#     date  unemployment
# 34  1982      9.708333
# 35  1983      9.600000
# 61  2009      9.283333
# 62  2010      9.608333
# 63  2011      8.933333

# %%
# Create your dataframe with column date
x = df_gdp_us['date']
x.head()
# Out:
# 0    1948
# 1    1949
# 2    1950
# 3    1951
# 4    1952
# Name: date, dtype: int64

# %%
gdp_change = df_gdp_us['change-current'] # Create your dataframe with column change-current
gdp_change.head()
# Out:
# 0    -0.7
# 1    10.0
# 2    15.7
# 3     5.9
# 4     6.0
# Name: change-current, dtype: float64

# %%
unemployment = df_unemp_us['unemployment'] # Create your dataframe with column unemployment
unemployment.head()
# Out:
# 0    3.750000
# 1    6.050000
# 2    5.208333
# 3    3.283333
# 4    3.025000
# Name: unemployment, dtype: float64

# %%
title = 'GDP and Unemployment Data'# Give your dashboard a string title

# %%
file_name = "index.html"

# %%
# Fill up the parameters in the following function:
make_dashboard(x=x, gdp_change=gdp_change, unemployment= unemployment, title=title, file_name=file_name)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="78ec416c-b6a5-4ee4-998f-1e67812c16ec"></div>
# </div>

# %%
credentials = {

   "apikey": "mjLh_wnsPHX1KqNAUZrI2ZOBIXL5cM6HWMeQdhhQpfdl",

   "cos_hmac_keys": {

    "access_key_id": "aacf6446bf6b470e9d742f945e8fc169", 

     "secret_access_key": "b6025b54131a6f170dde89c6d05068d90299b9cebb927706"

   },

 
    "endpoints": "https://s3.eu.cloud-object-storage.appdomain.cloud",

   "iam_apikey_description": "Auto-generated for key aacf6446-bf6b-470e-9d74-2f945e8fc169",

   "iam_apikey_name": "WDP-Editor-courserauseconomyproject-donotdelete-pr-fx2vhusqxaq2bc",

   "iam_role_crn": "crn:v1:bluemix:public:iam::::serviceRole:Writer",

    "iam_serviceid_crn": "crn:v1:bluemix:public:iam-identity::a/9135b6556a55433e87eeea2a5e3254b1::serviceid:ServiceId-47013691-de7c-403e-9f5d-0faa441ddfb2",

  "resource_instance_id": "crn:v1:bluemix:public:cloud-object-storage:global:a/9135b6556a55433e87eeea2a5e3254b1:89eff647-f774-4d9b-a74c-1b814db79783::"

}

# %%
# @hidden_cell
{
 
  "apikey": "mjLh_wnsPHX1KqNAUZrI2ZOBIXL5cM6HWMeQdhhQpfdl",
  "cos_hmac_keys": {
    "access_key_id": "aacf6446bf6b470e9d742f945e8fc169",
    "secret_access_key": "b6025b54131a6f170dde89c6d05068d90299b9cebb927706"
  },
  "endpoints": "https://control.cloud-object-storage.cloud.ibm.com/v2/endpoints",
  "iam_apikey_description": "Auto-generated for key aacf6446-bf6b-470e-9d74-2f945e8fc169",
  "iam_apikey_name": "WDP-Editor-courserauseconomyproject-donotdelete-pr-fx2vhusqxaq2bc",
  "iam_role_crn": "crn:v1:bluemix:public:iam::::serviceRole:Writer",
  "iam_serviceid_crn": "crn:v1:bluemix:public:iam-identity::a/9135b6556a55433e87eeea2a5e3254b1::serviceid:ServiceId-47013691-de7c-403e-9f5d-0faa441ddfb2",
  "resource_instance_id": "crn:v1:bluemix:public:cloud-object-storage:global:a/9135b6556a55433e87eeea2a5e3254b1:89eff647-f774-4d9b-a74c-1b814db79783::"

}
# Out:
# {'apikey': 'mjLh_wnsPHX1KqNAUZrI2ZOBIXL5cM6HWMeQdhhQpfdl',
#  'cos_hmac_keys': {'access_key_id': 'aacf6446bf6b470e9d742f945e8fc169',
#   'secret_access_key': 'b6025b54131a6f170dde89c6d05068d90299b9cebb927706'},
#  'endpoints': 'https://control.cloud-object-storage.cloud.ibm.com/v2/endpoints',
#  'iam_apikey_description': 'Auto-generated for key aacf6446-bf6b-470e-9d74-2f945e8fc169',
#  'iam_apikey_name': 'WDP-Editor-courserauseconomyproject-donotdelete-pr-fx2vhusqxaq2bc',
#  'iam_role_crn': 'crn:v1:bluemix:public:iam::::serviceRole:Writer',
#  'iam_serviceid_crn': 'crn:v1:bluemix:public:iam-identity::a/9135b6556a55433e87eeea2a5e3254b1::serviceid:ServiceId-47013691-de7c-403e-9f5d-0faa441ddfb2',
#  'resource_instance_id': 'crn:v1:bluemix:public:cloud-object-storage:global:a/9135b6556a55433e87eeea2a5e3254b1:89eff647-f774-4d9b-a74c-1b814db79783::'}

# %%
#endpoint = 'https://s3-api.us-geo.objectstorage.softlayer.net'
endpoint = 'https://s3.eu.cloud-object-storage.appdomain.cloud'

# %%
bucket_name = 'courserauseconomyproject-donotdelete-pr-fx2vhusqxaq2bc' # Type your bucket name on IBM Cloud

# %%
import boto3

# %%
resource = boto3.resource(
    's3',
    aws_access_key_id = credentials["cos_hmac_keys"]['access_key_id'],
    aws_secret_access_key = credentials["cos_hmac_keys"]["secret_access_key"],
    endpoint_url = endpoint,
)

# %%
import os

directory = os.getcwd()
html_path = directory + "/" + file_name

# %%
# Type your code here
f = open(html_path,'r')

# %%
# Fill up the parameters in the following function:
resource.Bucket(name=bucket_name).put_object(Key=file_name, Body=f.read())
# Out:
# s3.Object(bucket_name='courserauseconomyproject-donotdelete-pr-fx2vhusqxaq2bc', key='index.html')

# %%
# Fill in the value for each key
Params = {'Bucket':bucket_name ,'Key':file_name }

# %%
import sys
time = 7*24*60**2
client = boto3.client(
    's3',
    aws_access_key_id = credentials["cos_hmac_keys"]['access_key_id'],
    aws_secret_access_key = credentials["cos_hmac_keys"]["secret_access_key"],
    endpoint_url=endpoint,

)
url = client.generate_presigned_url('get_object',Params=Params,ExpiresIn=time)
print(url)
# Out:
# https://s3.eu.cloud-object-storage.appdomain.cloud/courserauseconomyproject-donotdelete-pr-fx2vhusqxaq2bc/index.html?Expires=1560333994&Signature=XNGotFWu0QW5%2BRSdtpA7doTJLWY%3D&AWSAccessKeyId=aacf6446bf6b470e9d742f945e8fc169
